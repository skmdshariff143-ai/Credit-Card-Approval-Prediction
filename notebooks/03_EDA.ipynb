# %% [markdown]
# # Exploratory Data Analysis
# **Purpose**: Visualizes distributions, outliers, and class target balances.
#
# This notebook outlines steps completed in this phase of the pipeline.

# %%
# Ingest packages
import pandas as pd
import numpy as np
print('Imports successful')
