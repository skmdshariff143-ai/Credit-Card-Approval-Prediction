# %% [markdown]
# # Data Dictionary & Key Statistics
# **Purpose**: Inspects data types, shapes, and unique counts.
#
# This notebook outlines steps completed in this phase of the pipeline.

# %%
# Ingest packages
import pandas as pd
import numpy as np
print('Imports successful')
