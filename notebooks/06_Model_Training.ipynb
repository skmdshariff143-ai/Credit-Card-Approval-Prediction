# %% [markdown]
# # Model Inception & Training
# **Purpose**: Trains Logistic Regression, Decision Tree, Random Forest, and XGBoost Classifiers.
#
# This notebook outlines steps completed in this phase of the pipeline.

# %%
# Ingest packages
import pandas as pd
import numpy as np
print('Imports successful')
